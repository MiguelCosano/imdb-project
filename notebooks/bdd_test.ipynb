# %%
# !docker-compose up -d db

# !docker-compose ps
# Out:
# [+] Running 3/3
#  ✔ Network imdb-project_default       Cr...                                0.0s
#  ✔ Volume imdb-project_postgres_data  Created                              0.0s
#  ✔ Container imdb-db                  Created                              0.0s
# [+] Running 3/3
#  ✔ Network imdb-project_default       Cr...                                0.0s
#  ✔ Volume imdb-project_postgres_data  Created                              0.0s
#  ✔ Container imdb-db                  Started                              0.1s
# NAME      IMAGE         COMMAND                  SERVICE   CREATED        STATUS                  PORTS
# imdb-db   postgres:15   "docker-entrypoint.s…"   db        1 second ago   Up Less than a second   0.0.0.0:5432->5432/tcp, [::]:5432->5432/tcp

# %%
import os
from sys import path
import os
from sqlalchemy import create_engine
import logging

logging.basicConfig(level=logging.INFO,format='%(asctime)s - %(levelname)s - %(message)s')

path.append(os.path.realpath("../"))

try:
   engine = create_engine(os.getenv("DATABASE_URL"))
   logging.info(f"Database created {engine.connect}")
    
except Exception as e:
    logging.error("Exception:", e)
# Out:
# 2025-12-06 14:59:23,389 - INFO - Database created <bound method Engine.connect of Engine(postgresql://imdb_user:***@localhost:5432/imdb)>

# %%
# !docker-compose down -v
# Out:
# [+] Running 0/1
#  ⠋ Container imdb-db  Stopping                                             0.1s
# [+] Running 2/3
#  ✔ Container imdb-db                  Removed                              0.1s
#  ⠋ Network imdb-project_default       Re...                                0.1s
#  ✔ Volume imdb-project_postgres_data  Removed                              0.0s
# [+] Running 2/3
#  ✔ Container imdb-db                  Removed                              0.1s
#  ⠙ Network imdb-project_default       Re...                                0.2s
#  ✔ Volume imdb-project_postgres_data  Removed                              0.0s
# [+] Running 3/3
#  ✔ Container imdb-db                  Removed                              0.1s
#  ✔ Network imdb-project_default       Re...                                0.2s
#  ✔ Volume imdb-project_postgres_data  Removed                              0.0s
